# %% [markdown]
# Étape 1 : Comprendre le dataset
#
# Avant de nettoyer, il faut répondre à quelques questions.

# %%
from google.colab import files

fichier = files.upload()
# Out:
#      <input type="file" id="files-03120576-fd2d-4b8d-bf76-86fdbe8a1fb6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03120576-fd2d-4b8d-bf76-86fdbe8a1fb6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **1- Importer le Dataset**

# %%
import pandas as pd

df = pd.read_csv("world-data-2023.csv")

df.head()
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %% [markdown]
# **2 - Nombres de lignes et de colonnes**

# %%
df.shape
# Out:
# (195, 35)

# %% [markdown]
# Le Dataset contient 195 observations, correspondant chacune à un Pays, et 35 variables décrivant différents indicateurs démographiques, économiques, sanitaires et environnementaux.

# %% [markdown]
# **3 - Afficher les premières lignes**

# %%
df.head(10)
# Out:
#                Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0          Afghanistan               60           AF                58.10%
# 1              Albania              105           AL                43.10%
# 2              Algeria               18           DZ                17.40%
# 3              Andorra              164           AD                40.00%
# 4               Angola               26           AO                47.50%
# 5  Antigua and Barbuda              223           AG                20.50%
# 6            Argentina               17           AR                54.30%
# 7              Armenia              104           AM                58.90%
# 8            Australia                3           AU                48.20%
# 9              Austria              109           AT                32.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# Les premières lignes montrent que chaque ligne représente un pays. Les colonnes regroupent des informations comme la population, le PIB, l'espérance de vie, les émissions de CO₂, etc. Certaines colonnes numériques semblent toutefois contenir des caractères spéciaux ($, %, ,) qui devront être nettoyés.

# %% [markdown]
# **4. Les Noms des Colonnes**

# %%
list(df.columns)
# Out:
# ['Country',
#  'Density\n(P/Km2)',
#  'Abbreviation',
#  'Agricultural Land( %)',
#  'Land Area(Km2)',
#  'Armed Forces size',
#  'Birth Rate',
#  'Calling Code',
#  'Capital/Major City',
#  'Co2-Emissions',
#  'CPI',
#  'CPI Change (%)',
#  'Currency-Code',
#  'Fertility Rate',
#  'Forested Area (%)',
#  'Gasoline Price',
#  'GDP',
#  'Gross primary education enrollment (%)',
#  'Gross tertiary education enrollment (%)',
#  'Infant mortality',
#  'Largest city',
#  'Life expectancy',
#  'Maternal mortality ratio',
#  'Minimum wage',
#  'Official language',
#  'Out of pocket health expenditure',
#  'Physicians per thousand',
#  'Population',
#  'Population: Labor force participation (%)',
#  'Tax revenue (%)',
#  'Total tax rate',
#  'Unemployment rate',
#  'Urban_population',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# Les noms des colonnes contiennent des espaces et des majuscules. Ils seront uniformisés, (minuscules et underscores) afin de faciliter leur utilisation avec Pandas et SQL.

# %% [markdown]
# **5. Les types de données**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %% [markdown]
# Dans le **commentaire** :
#
# Plusieurs colonnes numériques sont reconnues comme des chaînes de caractères (object), probablement à cause de la présence de symboles ($, %, ,). Elles devront être converties en types numériques après nettoyage.

# %% [markdown]
# **6. Les statistiques descriptives**

# %%
df.describe()
# Out:
#        Birth Rate  Calling Code  Fertility Rate  Infant mortality  \
# count  189.000000    194.000000      188.000000        189.000000
# mean    20.214974    360.546392        2.698138         21.332804
# std      9.945774    323.236419        1.282267         19.548058
# min      5.900000      1.000000        0.980000          1.400000
# 25%     11.300000     82.500000        1.705000          6.000000
# 50%     17.950000    255.500000        2.245000         14.000000
# 75%     28.750000    506.750000        3.597500         32.700000
# max     46.080000   1876.000000        6.910000         84.500000
#
#        Life expectancy  Maternal mortality ratio  Physicians per thousand  \
# count       187.000000                181.000000               188.000000
# mean         72.279679                160.392265                 1.839840
# std           7.483661                233.502024                 1.684261
# min          52.800000                  2.000000                 0.010000
# ...

# %% [markdown]
# Tu obtiens :
#
# moyenne ;
# minimum ;
# maximum ;
# quartiles.
#
# Puis :

# %%
df.describe(include="object")
# Out:
#             Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# count           195              195          188                   188
# unique          195              137          188                   168
# top     Afghanistan               25           AF                17.40%
# freq              1                7            1                     3
#
#        Land Area(Km2) Armed Forces size Capital/Major City Co2-Emissions  \
# count             194               171                192           188
# unique            194               105                192           184
# top           652,230             2,000              Kabul        28,284
# freq                1                 7                  1             2
#
#            CPI CPI Change (%)  ... Largest city Minimum wage  \
# count      178            179  ...          189          150
# unique     175             86  ...          188          114
# ...

# %% [markdown]
# Pour les colonnes texte

# %% [markdown]
# **Commentaire :**
#
# Les statistiques descriptives permettent de détecter des valeurs potentiellement aberrantes et de mieux comprendre la distribution des variables numériques.

# %% [markdown]
# 7. **Les Valeurs Manquantes**

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# Minimum wage                                 23.076923
# Tax revenue (%)                              13.333333
# Armed Forces size                            12.307692
# Gasoline Price                               10.256410
# Unemployment rate                             9.743590
# Population: Labor force participation (%)     9.743590
# CPI                                           8.717949
# CPI Change (%)                                8.205128
# Currency-Code                                 7.692308
# Maternal mortality ratio                      7.179487
# Total tax rate                                6.153846
# Gross tertiary education enrollment (%)       6.153846
# Life expectancy                               4.102564
# Abbreviation                                  3.589744
# Gross primary education enrollment (%)        3.589744
# Physicians per thousand                       3.589744
# Forested Area (%)                             3.589744
# ...

# %% [markdown]
# Certaines variables présentent des valeurs manquantes, leur traitement sera défini lors de l'étape de nettoyage en fonction de leur importance pour l'analyse.

# %% [markdown]
# **8- LES DOUBLONS**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Commentaire : **
# Cette vérification permet de s'assurer qu'aucun pays n'est présent plusieurs fois dans le dataset.

# %% [markdown]
# Premières Anomalies Observées:
# - Plusieurs colonnes numériques sont importées comme des chaines de carctères (object).
# - Des valeurs manquantes sont présentes dans certaines variables.
# - Les noms de colonnes contiennent des espaces et des majuscules.
# - Certaines valeurs numériques incluent des symboles ($, %, ,) qui empèchent leur conversion directe.
